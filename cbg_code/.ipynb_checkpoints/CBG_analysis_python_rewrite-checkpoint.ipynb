# %% [markdown]
# ### cbg data analysis - python rewrite

# %%
import numpy as np
import pandas as pd
import glob
import xgboost as xgb

from numpy import asarray
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from matplotlib import pyplot

# %%
dataset = 'huge'
days_n = 21
minimum_n_cbgs = days_n + 2

hypothreshold = 3

# %%
load_path = "/media/psf/Home/Documents/data/CBGdata"
rowLimit = 200000

df = pd.read_csv(f"{load_path}/{dataset}_unipoc_time_series_cohort_first_{days_n}_days.csv",
                     nrows = rowLimit, header = 0)

# %%
# exclude rows based on location
pre_removal_rows = df.shape[0]
exclude_vector = ['dialysis', 'Dialysis Centre - Level 2','renal',
                  'abbott', 'Ketones', 'Lab point of care room -IN',
                  'ARU2 Ketones', 'ED Ketones', 'REndoscopy Unit',
                  'LAB - Sent back to Abbott', 'Biochemistryx',
                  'Renal G6 Dialysis', 'Wd 5B Ketones', 'AAU Ketones',
                  'Dead meters', 'Lab Study room back to abbott',
                  'Health at Heart', 'A&E Ketones', 'IAU Ketones',
                  'MAU Office (Ketone)', 'OLD PXP Meters', 'Wd 6D Ketones',
                  'BIO POOL meters', 'OBSOLETE METERS 2', 'Meterx not found',
                  'X Ray', 'X-ray', 'training', 'staff', 'MAU (Ketone)',
                  'more dead meters',
                  'LOST IN DRUM', 'Labour Suite',
                  'returned', 'obsolete', 'old', 'Meterx',
                  'dead', 'BioChemistry', 'weldon', 'Pre Ass clinic Gen OP',
                  'radiology', 'outpatient', 'rcas', 'Meter not found', 'spare meters',
                  'Labour Ward', 'Neonatal Unit Top Floor']
df = df[~df['loc'].isin(exclude_vector)]
post_removal_rows = df.shape[0]

# df['loc'].unique() ## show all loc values

print(f'{pre_removal_rows - post_removal_rows} rows removed on loc')

id_pre_removal_rows = df.shape[0]
id_exclude_vector = [222222222222222]

df = df[~df['uID'].isin(id_exclude_vector)]
id_post_removal_rows = df.shape[0]

print(f'{id_pre_removal_rows - id_post_removal_rows} rows removed on uID')
# Out:
# 4339 rows removed on loc
# 0 rows removed on uID

# %%
# add unique ID by 2 cols - uID and admission vec
df = df.copy()
df['id_gp'] = df.groupby(['uID', 'admission_vec']).ngroup()

# %%
# convert to pandas datetime format and generate a day only col
df['datetimeIndex'] = pd.to_datetime(df['datetime'])
df['just_date'] = df['datetimeIndex'].dt.date

# %%
df.groupby(['id_gp']).size()
df['admission_days'] = df['just_date'].groupby(df['id_gp']).transform('diff')

# %%
df.groupby('id_gp')['just_date'].agg(np.ptp)
# Out:
# id_gp
# 0      335 days
# 1      415 days
# 2      333 days
# 3      333 days
# 4      334 days
#          ...
# 2023   334 days
# 2024   273 days
# 2025   334 days
# 2026   304 days
# 2027   334 days
# Name: just_date, Length: 2028, dtype: timedelta64[ns]

# %%
df[df['id_gp']==0]
# Out:
#           uID  admission_vector             datetime   Glu  \
# 0   101176147                 8  18/02/2016  4:17PM   10.4
# 1   101176147                 8  20/02/2016  6:57AM    4.9
# 3       101176147                 8  20/02/2016  6:50PM    9.8
# 4       101176147                 8  20/02/2016 11:30PM   11.8
# ...           ...               ...                  ...   ...
# 199995  407416145                 1  10/04/2013 11:50AM    9.2
# 199996  407416145                 1  11/04/2013  4:11PM    7.4
# 199997  407416145                 1  11/04/2013  9:18PM   11.8
# 199998  407416145                 1  12/04/2013  6:57AM    5.9
# 199999  407416145                 1  12/04/2013  4:49PM    9.6
#
#                               loc             dateTime  unix_dateTime  \
# 0       Immediate Assessment Unit  2016-02-18 16:17:00   1.455812e+09
# 1                              8A  2016-02-20 06:57:00   1.455951e+09
# 2                              8A  2016-02-20 14:17:00   1.455978e+09
# 3                              8A  2016-02-20 18:50:00   1.455994e+09
# 4                              8A  2016-02-20 23:30:00   1.456011e+09
# ...                           ...                  ...            ...
# 199995                    Ward 64  2013-04-10 11:50:00   1.365591e+09
# 199996                    Ward 64  2013-04-11 16:11:00   1.365693e+09
# 199997                    Ward 64  2013-04-11 21:18:00   1.365711e+09
# 199998                    Ward 64  2013-04-12 06:57:00   1.365746e+09
# 199999                    Ward 64  2013-04-12 16:49:00   1.365782e+09
#
#         n_admissions  interval_seconds  interval_days    n    N  \
# 0                9.0           2299920             27    1   36
# 1                9.0           2299920             27    2   36
# 2                9.0           2299920             27    3   36
# 3                9.0           2299920             27    4   36
# 4                9.0           2299920             27    5   36
# ...              ...               ...            ...  ...  ...
# 199995           3.0           1958640             23   98  102
# 199996           3.0           1958640             23   99  102
# 199997           3.0           1958640             23  100  102
# 199998           3.0           1958640             23  101  102
# 199999           3.0           1958640             23  102  102
#
#         new_interval_seconds  admission_vec  id_gp       datetimeIndex  \
# 0                    2299920              1      0 2016-02-18 16:17:00
# 1                    2299920              1      0 2016-02-20 06:57:00
# 2                    2299920              1      0 2016-02-20 14:17:00
# 3                    2299920              1      0 2016-02-20 18:50:00
# 4                    2299920              1      0 2016-02-20 23:30:00
# ...                      ...            ...    ...                 ...
# 199995               1958640              1   2027 2013-10-04 11:50:00
# 199996               1958640              1   2027 2013-11-04 16:11:00
# 199997               1958640              1   2027 2013-11-04 21:18:00
# 199998               1958640              1   2027 2013-12-04 06:57:00
# 199999               1958640              1   2027 2013-12-04 16:49:00
#
#          just_date  min_glu
# 0       2016-02-18      3.8
# 1       2016-02-20      3.8
# 2       2016-02-20      3.8
# 3       2016-02-20      3.8
# 4       2016-02-20      3.8
# ...            ...      ...
# 199995  2013-10-04      2.3
# 199996  2013-11-04      2.3
# 199997  2013-11-04      2.3
# 199998  2013-12-04      2.3
# 199999  2013-12-04      2.3
#
# [195661 rows x 18 columns]

# %%
df['just_date'].groupby(df['id_gp']).transform('size')
# Out:
# 0          36
# 1          36
# 2          36
# 3          36
# 4          36
#          ...
# 199995    102
# 199996    102
# 199997    102
# 199998    102
# 199999    102
# Name: just_date, Length: 195661, dtype: int64
